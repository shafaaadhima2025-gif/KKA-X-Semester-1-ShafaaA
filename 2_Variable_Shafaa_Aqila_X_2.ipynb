# %% [markdown]
# <a href="https://colab.research.google.com/github/shafaaadhima2025-gif/KKA-X-Semester-1-ShafaaA/blob/main/2_Variable_Shafaa_Aqila_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama: Shafaa Aqila
Kelas: X.2
No.Absen: 34

# %% [markdown]
# #Konsep Dasar Variable

# %%
print("shafaaadhima2025@gmail.com")
print("shafaaadhima2025@gmail.com")
print("shafaaadhima2025@gmail.com")
# Out:
# shafaaadhima2025@gmail.com
# shafaaadhima2025@gmail.com
# shafaaadhima2025@gmail.com

# %%
email_user = "shafaaadhima2025@gmail.com"
print(email_user)
print(email_user)
print(email_user)
# Out:
# shafaaadhima2025@gmail.com
# shafaaadhima2025@gmail.com
# shafaaadhima2025@gmail.com

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
If = "Handayani"
print (If)
# Out:
# Handayani

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
#Sensitif terhadap penulisan kapital
USIA = 17

# %%
print(USIA)
# Out:
# 17

# %%
_= "Fazel Wardana"
_= "Lia Wati"

# %%
print(_)
# Out:
# Lia Wati

# %% [markdown]
# #Assignment

# %%
#single assignment
bb_fazel = 55
bb_dani= 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#Multiple assignment
bb_fazel, bb_dani = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
nama_siswa_1, nama_siswa_2 ="deni", "doni"
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
#Chain assignment
bb_hasbi = bb_dani = 60
print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# #Cara menulis operator pada phyton

# %%
#Tanpa Variabel
print(9+6)
# Out:
# 15

# %%
print ("shinta")
# Out:
# shinta

# %%
print ("9+6")
# Out:
# 9+6

# %%
#Operand disimpan ke variabel
jualan_hp_habibi = 10
jualan_hp_syauqi = 6

print(jualan_hp_habibi+jualan_hp_syauqi)
# Out:
# 16

# %%
#Hasil operasi disimpan ke variabel
total_hp = 10+6
print(total_hp)
# Out:
# 16

# %%
#Operan dan hasil operasi disimpan ke variable
jualan_hp_habibi = 10
jualan_hp_syauqi = 6
total_h = jualan_hp_habibi+jualan_hp_syauqi
print(total_hp)
# Out:
# 16

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<9)
# Out:
# True

# %%
print(8>10)
# Out:
# False
