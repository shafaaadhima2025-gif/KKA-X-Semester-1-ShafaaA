# %% [markdown]
# <a href="https://colab.research.google.com/github/shafaaadhima2025-gif/KKA-X-Semester-1-ShafaaA/blob/main/3_Aplikasi_Kalkulator_Sederhana_Shafaa_AA_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari_jari = int(input("Jari jari tabung adalah (cm): "))
tinggi = int(input("Tinggi tabung adalah (cm): "))

volume = 22/7 * jari_jari * jari_jari * tinggi

print(f"\n Volume Tabung yaitu {volume} cm^3")
# Out:
# Jari jari tabung adalah (cm): 5
# Tinggi tabung adalah (cm): 5
#
#  Volume Tabung yaitu 392.85714285714283 cm^3

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar dari persegi panjang (cm): 5
#
# Luas dari persegi panjang yaitu 25 cm^2
